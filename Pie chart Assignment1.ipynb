# %%
import matplotlib.pyplot as plt

# %%
gm=[46,27,26,19,17]
con=['United States','Great Britain','China','Russia','Germany']
colors=['red','yellow','blue','green','gold']
arr=(0.1,0,0,0,0)
plt.pie(gm,labels=con,colors=colors,autopct='%.1f%%',explode=arr,shadow=True)
plt.axis('equal')
plt.show()
